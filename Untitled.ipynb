# %%
import pandas as pd
# Out:
# C:\Users\jprin\AppData\Local\Temp\ipykernel_33716\217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df1 = pd.read_csv('202501_CombinedData.csv')
df2 = pd.read_csv('202502_CombinedData.csv')
df3 = pd.read_csv('202503_CombinedData.csv')
df4 = pd.read_csv('202504_CombinedData.csv')
print(df1.info())
print(df1.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51750 entries, 0 to 51749
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   visibility           51701 non-null  float64
#  1   datetime             51750 non-null  object
#  2   main.temp            51750 non-null  float64
#  3   main.feels_like      51750 non-null  float64
#  4   main.temp_min        51750 non-null  float64
#  5   main.temp_max        51750 non-null  float64
#  6   main.pressure        51750 non-null  float64
#  7   main.humidity        51750 non-null  float64
#  8   main.sea_level       51750 non-null  float64
#  9   main.grnd_level      51750 non-null  float64
#  10  wind.speed           51750 non-null  float64
#  11  wind.deg             51750 non-null  float64
#  12  wind.gust            45923 non-null  float64
#  13  clouds.all           51750 non-null  float64
#  14  sys.sunrise          51750 non-null  object
# ...

# %%
print(df2.info())
print(df2.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53166 entries, 0 to 53165
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   visibility           53086 non-null  float64
#  1   datetime             53166 non-null  object
#  2   main.temp            53166 non-null  float64
#  3   main.feels_like      53166 non-null  float64
#  4   main.temp_min        53166 non-null  float64
#  5   main.temp_max        53166 non-null  float64
#  6   main.pressure        53166 non-null  float64
#  7   main.humidity        53166 non-null  float64
#  8   main.sea_level       53166 non-null  float64
#  9   main.grnd_level      53166 non-null  float64
#  10  wind.speed           53166 non-null  float64
#  11  wind.deg             53166 non-null  float64
#  12  wind.gust            46969 non-null  float64
#  13  clouds.all           53166 non-null  float64
#  14  sys.sunrise          53166 non-null  object
# ...

# %%
print(df3.info())
print(df3.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82807 entries, 0 to 82806
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   visibility           82750 non-null  float64
#  1   datetime             82807 non-null  object
#  2   main.temp            82807 non-null  float64
#  3   main.feels_like      82807 non-null  float64
#  4   main.temp_min        82807 non-null  float64
#  5   main.temp_max        82807 non-null  float64
#  6   main.pressure        82807 non-null  float64
#  7   main.humidity        82807 non-null  float64
#  8   main.sea_level       82807 non-null  float64
#  9   main.grnd_level      82807 non-null  float64
#  10  wind.speed           82807 non-null  float64
#  11  wind.deg             82807 non-null  float64
#  12  wind.gust            71044 non-null  float64
#  13  clouds.all           82807 non-null  float64
#  14  sys.sunrise          82807 non-null  object
# ...

# %%
print(df4.info())
print(df4.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97238 entries, 0 to 97237
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   visibility           97235 non-null  float64
#  1   datetime             97238 non-null  object
#  2   main.temp            97238 non-null  float64
#  3   main.feels_like      97238 non-null  float64
#  4   main.temp_min        97238 non-null  float64
#  5   main.temp_max        97238 non-null  float64
#  6   main.pressure        97238 non-null  float64
#  7   main.humidity        97238 non-null  float64
#  8   main.sea_level       97238 non-null  float64
#  9   main.grnd_level      97238 non-null  float64
#  10  wind.speed           97238 non-null  float64
#  11  wind.deg             97238 non-null  float64
#  12  wind.gust            81716 non-null  float64
#  13  clouds.all           97238 non-null  float64
#  14  sys.sunrise          97238 non-null  object
# ...

# %%
city = 'Iloilo City'
city_data1 = df1[df1['city_name'] == city]
city_data2 = df2[df2['city_name'] == city]
city_data3 = df3[df3['city_name'] == city]  
city_data4 = df4[df4['city_name'] == city]

# %%
print(city_data1.head(5))
print(city_data1.info())
print(city_data1.shape)
# Out:
#      visibility                   datetime  main.temp  main.feels_like  \
# 59      10000.0  2025-01-01 00:07:53+08:00      24.78            25.64
# 197     10000.0  2025-01-01 02:07:53+08:00      24.70            25.58
# 335     10000.0  2025-01-01 04:07:50+08:00      24.80            25.66
# 473     10000.0  2025-01-01 06:07:52+08:00      24.67            25.54
# 611     10000.0  2025-01-01 08:07:55+08:00      25.95            25.95
#
#      main.temp_min  main.temp_max  main.pressure  main.humidity  \
# 59           24.78          24.78         1010.0           89.0
# 197          24.70          24.70         1009.0           90.0
# 335          24.80          24.80         1009.0           89.0
# 473          24.67          24.67         1009.0           90.0
# 611          25.95          25.95         1011.0           87.0
#
#      main.sea_level  main.grnd_level  wind.speed  wind.deg  wind.gust  \
# 59           1010.0           1009.0        3.43       5.0       7.88
# ...

# %%
print(city_data2.head(5))
print(city_data2.info())
print(city_data2.shape)
# Out:
#      visibility                   datetime  main.temp  main.feels_like  \
# 59      10000.0  2025-02-01 00:07:54+08:00      25.82            26.57
# 197     10000.0  2025-02-01 02:06:37+08:00      25.46            26.23
# 335     10000.0  2025-02-01 04:07:47+08:00      24.76            25.54
# 473     10000.0  2025-02-01 06:05:41+08:00      24.58            25.37
# 611     10000.0  2025-02-01 08:07:51+08:00      26.40            26.40
#
#      main.temp_min  main.temp_max  main.pressure  main.humidity  \
# 59           25.82          25.82         1009.0           81.0
# 197          25.46          25.46         1008.0           83.0
# 335          24.76          24.76         1008.0           86.0
# 473          24.58          24.58         1009.0           87.0
# 611          26.40          26.40         1010.0           79.0
#
#      main.sea_level  main.grnd_level  wind.speed  wind.deg  wind.gust  \
# 59           1009.0           1008.0        5.66      32.0       9.66
# ...

# %%
print(city_data3.head(5))
print(city_data3.info())
print(city_data3.shape)
# Out:
#      visibility                   datetime  main.temp  main.feels_like  \
# 59      10000.0  2025-03-01 00:01:51+08:00      25.14            25.90
# 330     10000.0  2025-03-01 01:57:10+08:00      24.67            25.46
# 466     10000.0  2025-03-01 03:01:56+08:00      24.74            25.49
# 602     10000.0  2025-03-01 04:00:34+08:00      24.69            25.46
# 738     10000.0  2025-03-01 05:02:12+08:00      24.53            25.31
#
#      main.temp_min  main.temp_max  main.pressure  main.humidity  \
# 59           25.14          25.14         1012.0           84.0
# 330          24.67          24.67         1011.0           87.0
# 466          24.74          24.74         1011.0           85.0
# 602          24.69          24.69         1010.0           86.0
# 738          24.53          24.53         1011.0           87.0
#
#      main.sea_level  main.grnd_level  wind.speed  wind.deg  wind.gust  \
# 59           1012.0           1011.0        7.04       9.0      11.52
# ...

# %%
print(city_data4.head(5))
print(city_data4.info())
print(city_data4.shape)
# Out:
#      visibility                   datetime  main.temp  main.feels_like  \
# 59      10000.0  2025-04-01 00:01:47+08:00      24.75            25.42
# 194     10000.0  2025-04-01 01:01:51+08:00      24.51            25.16
# 332     10000.0  2025-04-01 02:01:49+08:00      24.49            25.14
# 468     10000.0  2025-04-01 03:01:54+08:00      24.24            24.86
# 605     10000.0  2025-04-01 04:01:55+08:00      24.06            24.71
#
#      main.temp_min  main.temp_max  main.pressure  main.humidity  \
# 59           24.75          24.75         1010.0           82.0
# 194          24.51          24.51         1009.0           82.0
# 332          24.49          24.49         1009.0           82.0
# 468          24.24          24.24         1009.0           82.0
# 605          24.06          24.06         1009.0           84.0
#
#      main.sea_level  main.grnd_level  wind.speed  wind.deg  wind.gust  \
# 59           1010.0           1009.0        3.21      26.0       5.62
# ...

# %%
January = city_data1.drop(columns=['sys.sunrise', 'sys.sunset', 'main.sea_level', 'main.grnd_level', 'weather.description', 'wind.gust', 'wind.deg'])
February = city_data2.drop(columns=['sys.sunrise', 'sys.sunset', 'main.sea_level', 'main.grnd_level', 'weather.description', 'wind.gust', 'wind.deg'])
March = city_data3.drop(columns=['sys.sunrise', 'sys.sunset', 'main.sea_level', 'main.grnd_level', 'weather.description', 'wind.gust', 'wind.deg'])
April = city_data4.drop(columns=['sys.sunrise', 'sys.sunset', 'main.sea_level', 'main.grnd_level', 'weather.description', 'wind.gust', 'wind.deg'])

# %%
print(January.head(5))
# Out:
#      visibility                   datetime  main.temp  main.feels_like  \
# 59      10000.0  2025-01-01 00:07:53+08:00      24.78            25.64
# 197     10000.0  2025-01-01 02:07:53+08:00      24.70            25.58
# 335     10000.0  2025-01-01 04:07:50+08:00      24.80            25.66
# 473     10000.0  2025-01-01 06:07:52+08:00      24.67            25.54
# 611     10000.0  2025-01-01 08:07:55+08:00      25.95            25.95
#
#      main.temp_min  main.temp_max  main.pressure  main.humidity  wind.speed  \
# 59           24.78          24.78         1010.0           89.0        3.43
# 197          24.70          24.70         1009.0           90.0        4.00
# 335          24.80          24.80         1009.0           89.0        3.46
# 473          24.67          24.67         1009.0           90.0        3.71
# 611          25.95          25.95         1011.0           87.0        5.16
#
#      clouds.all weather.main    city_name  rain.1h
# ...
